# %% [markdown]
# <a href="https://colab.research.google.com/github/Manohar4587/Gun_Object_Detection/blob/main/November_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.4/898.4 kB 49.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/gun-roboflow')

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (pretrained)
model = YOLO('yolov8s.pt')  # Switch to 'yolov8s.pt' for better accuracy with a small dataset

# Train the model on the custom dataset
results = model.train(
    data='/content/drive/My Drive/gun-roboflow/data.yaml',  # path to the data yaml file
    epochs=50,  # Increased epochs for more training time
    imgsz=640,  # Reduced image size for stability
    batch=16,   # Increase batch size if hardware allows
    name='gun-detection',
    optimizer='AdamW',  # Use AdamW for stable convergence
    lr0=0.001,  # Lower learning rate for gradual training
    #device='cpu'  # or 'gpu' if available
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.43 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from google.colab import files
files.download('runs/detect/gun-detection4/weights/best.pt')

# %%
# Run inference on a test image
import os

test_dir = '/content/drive/My Drive/Gun_Object_Detection-main 2/Gun_Object_Detection-main/test_images' # Set a lower confidence threshold if needed
#results.show()  # Display the detection results
for img_name in os.listdir(test_dir):
    img_path = os.path.join(test_dir, img_name)
    results = model(img_path, conf=0.50)
    if isinstance(results, list):
      for result in results:
          result.show()
# Out:
# image 1/1 /content/drive/My Drive/Gun_Object_Detection-main 2/Gun_Object_Detection-main/test_images/Img82.jpg: 288x640 1 gun, 1 PERSON, 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
# <PIL.Image.Image image mode=RGB size=600x255>
# image 1/1 /content/drive/My Drive/Gun_Object_Detection-main 2/Gun_Object_Detection-main/test_images/Img88.jpg: 288x640 1 gun, 1 PERSON, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
# <PIL.Image.Image image mode=RGB size=600x256>
# image 1/1 /content/drive/My Drive/Gun_Object_Detection-main 2/Gun_Object_Detection-main/test_images/Img60.jpg: 288x640 1 gun, 1 PERSON, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
# <PIL.Image.Image image mode=RGB size=600x253>
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 22.5 MB/s eta 0:00:00
# ...

# %%
import os
import cv2
import mediapipe as mp
import numpy as np
from ultralytics import YOLO  # Assuming YOLOv8 is being used

# Initialize Mediapipe pose and YOLO model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=1,
                    min_detection_confidence=0.7, min_tracking_confidence=0.7)


model = YOLO('runs/detect/gun-detection5/weights/best.pt')

# Path to test images
test_dir = '/content/drive/My Drive/gun-roboflow/test_set'
output_dir = '/content/drive/My Drive/gun-roboflow/output'  # Directory to save annotated images
os.makedirs(output_dir, exist_ok=True)  # Create output directory if it doesn't exist
counter = 0

# Iterate through test images
for img_name in os.listdir(test_dir):
    img_path = os.path.join(test_dir, img_name)
    counter += 1

    # Read the image
    image = cv2.imread(img_path)
    image_height, image_width, _ = image.shape

    # Run YOLO inference
    results = model(img_path, conf=0.2)  # Lower confidence threshold for partial detections

    # Extract YOLO detections
    detections = results[0].boxes


    class_ids = detections.cls.cpu().numpy().astype(int)
    bounding_boxes = detections.xyxy.cpu().numpy().astype(int)

    # Separate persons and guns
    persons = bounding_boxes[class_ids == 1]
    guns = bounding_boxes[class_ids == 0]

    # Process each detected person
    for person in persons:
        x_min, y_min, x_max, y_max = person

        # Expand the bounding box for better coverage
        padding = 20
        x_min = max(0, x_min - padding)
        y_min = max(0, y_min - padding)
        x_max = min(image_width, x_max + padding)
        y_max = min(image_height, y_max + padding)

        # Crop the person region
        person_crop = image[y_min:y_max, x_min:x_max]

        # Convert the cropped region to RGB for MediaPipe
        person_rgb = cv2.cvtColor(person_crop, cv2.COLOR_BGR2RGB)

        # Run pose estimation
        pose_results = pose.process(person_rgb)

        hand_positions = []

        if pose_results.pose_landmarks:
            for idx, landmark in enumerate(pose_results.pose_landmarks.landmark):
                if idx in [15, 16]:  # Right hand (16) and left hand (15) landmarks
                    x = int(landmark.x * (x_max - x_min) + x_min)
                    y = int(landmark.y * (y_max - y_min) + y_min)
                    hand_positions.append((x, y))
                    cv2.circle(image, (x, y), 5, (0, 255, 0), -1)  # Draw hand keypoints
        else:
            # Fallback for approximate hand positions if landmarks are missing
            hand_positions = [
                (x_min + (x_max - x_min) // 4, y_min),  # Left hand (approx)
                (x_min + 3 * (x_max - x_min) // 4, y_min)  # Right hand (approx)
            ]

        # Analyze hand proximity to guns
        for gun in guns:
            gx_min, gy_min, gx_max, gy_max = gun
            gun_center = ((gx_min + gx_max) // 2, (gy_min + gy_max) // 2)

            # Check if any hand is near the gun
            for hand in hand_positions:
                hx, hy = hand
                distance = ((hx - gun_center[0]) ** 2 + (hy - gun_center[1]) ** 2) ** 0.5
                distance_threshold = max((gx_max - gx_min) * 0.5, 50)  # Dynamic threshold

                if distance < distance_threshold:  # Threat detected
                    cv2.putText(image, "Threat Detected!", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                    cv2.rectangle(image, (gx_min, gy_min), (gx_max, gy_max), (0, 0, 255), 2)  # Red box for guns
                    break

    # Save the annotated image to the output directory
    output_path = os.path.join(output_dir, img_name)
    cv2.imwrite(output_path, image)

print(f"Processed {counter} images and saved to {output_dir}.")
# Out:
# image 1/1 /content/drive/My Drive/gun-roboflow/test_set/test_image_3.jpg: 640x640 1 gun, 1 PERSON, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/My Drive/gun-roboflow/test_set/test_image_1.jpg: 640x640 1 gun, 1 PERSON, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/My Drive/gun-roboflow/test_set/test_image_2.jpg: 640x640 1 gun, 1 PERSON, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/My Drive/gun-roboflow/test_set/test_image_9.jpg: 384x640 3 guns, 2 PERSONs, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/My Drive/gun-roboflow/test_set/test_image_5.jpg: 416x640 1 gun, 1 PERSON, 9.0ms
# ...
